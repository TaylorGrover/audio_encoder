# %% [markdown]
# # Data Loading and Preprocessing

# %%
from autoencoder import *
import glob
from IPython.display import Audio
# Out:
# 2022-12-04 01:18:13.728725: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-04 01:18:13.731710: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-04 01:18:13.731718: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
def get_audio(filepaths, num_vectors=100, sr=22050):
    """
    Currently really slow: approximately 34 files read per second, but there are
    over 100,000 files
    """
    zipped_fname = f"raw_audio_{sr}.zip"
    audio_fname = f"raw_audio_{sr}.npy"
    audio = []
    np.random.shuffle(filepaths)
    start = time.time()
    random_indices = [i for i in range(num_vectors)]
    np.random.shuffle(random_indices)
    '''with ProcessPoolExecutor(max_workers=3) as exe:
        completed = exe.map(get_single_file, filepaths[:num_vectors], repeat(sr), chunksize=40)
        for item in completed:
            if item.shape[0] == sr:
                audio.append(item)'''
    if os.path.isfile(zipped_fname):
        with zipfile.ZipFile(zipped_fname, "r") as zip_ref:
            with zip_ref.open(audio_fname) as unzipped:
                audio = np.load(unzipped)
                print(time.time() - start)
                return audio[random_indices]
    for i, path in enumerate(filepaths):
        if i >= num_vectors:
            break
        X, sample_rate = librosa.load(path, sr=sr)
        if X.shape[0] != sample_rate:
            X = librosa.util.fix_length(X, size=sr)
        audio.append(X)
    print(time.time() - start)
    with zipfile.ZipFile(zipped_fname, "w") as zip_ref:
        np.save(audio_fname.replace(".npy", ""), audio)
        zip_ref.write(audio_fname)
    return np.array(audio, dtype=np.float32)[random_indices]

# %%
sr = 22050
filepaths = get_all_files("wav")
audio = get_audio(filepaths, num_vectors=3000, sr=sr)
# Out:
# 0
# 0
# 0.0005669593811035156
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [15], in <cell line: 3>()
#       1 sr = 22050
#       2 filepaths = get_all_files("wav")
# ----> 3 audio = get_audio(filepaths, num_vectors=3000, sr=sr)
#
# Input In [14], in get_audio(filepaths, num_vectors, sr)
#      23             print(len(audio))
#      24             print(time.time() - start)
# ---> 25             return audio[random_indices]
#      26 for i, path in enumerate(filepaths):
#      27     if i >= num_vectors:
#
# IndexError: index 2145 is out of bounds for axis 0 with size 0

# %%
X_train, X_test = conv_data(audio, sr)
# Out:
# 2.8779869079589844

# %% [markdown]
# # Audio Visualization

# %%
Audio(audio[0], rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(audio[0])

# %%
fig, ax = plt.subplots(figsize=(10, 6))
index = np.random.randint(0, len(audio))
mel = librosa.feature.melspectrogram(y=audio[0], sr=sr, n_mels=64)
mel_to_db = librosa.amplitude_to_db(mel, ref=np.max)
librosa.display.specshow(mel_to_db, x_axis="time", y_axis="log", ax=ax)
reshaped = mel.reshape(*mel.shape, 1)
fig.savefig("asdf.png")

# %% [markdown]
# # Plot Random Melspectrograms

# %%
X_test.shape
# Out:
# (900, 64, 44, 1)

# %% [markdown]
# # Get Convolutional Model

# %%
def get_conv_model(input_shape, latent_units = 50):
    Input = tf.keras.Input(shape=input_shape)
    #encoder = Sequential()
    x = layers.Conv2D(64, (3, 3), input_shape=input_shape, activation="leaky_relu", padding="same")(Input)
    x = layers.MaxPool2D((2, 2), padding="same")(x)
    x = layers.
    #print(encoder.summary())
    #latent = encoder(Input)
    #decoder = Sequential()
    x = layers.Conv2DTranspose(64, (3, 3), strides=2, activation="leaky_relu", padding="same")(x)
    x = layers.Conv2D(1, (1, 1), activation="linear")(x)
    print(x.shape)
    #print(decoder.summary())

    model = Model(inputs=Input, outputs=x)
    print(model.summary())
    model.compile(optimizer="adam", loss="MSE")
    return model

# %%
latent = 1000
print(X_train.shape[1:])
model = get_conv_model(X_train.shape[1:], latent)
# Out:
# (64, 44, 1)
# (None, 64, 44, 1)
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 64, 44, 1)]       0
#
#  conv2d_62 (Conv2D)          (None, 64, 44, 64)        640
#
#  max_pooling2d_45 (MaxPoolin  (None, 32, 22, 64)       0
#  g2D)
#
#  conv2d_transpose_43 (Conv2D  (None, 64, 44, 64)       36928
#  Transpose)
#
#  conv2d_63 (Conv2D)          (None, 64, 44, 1)         65
#
# =================================================================
# Total params: 37,633
# Trainable params: 37,633
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model_name = f"mel_{sr}_{latent}_{model.loss}"
checkpoint_callback = get_checkpoint(model_name)
model.fit(X_train, X_train, epochs=20, batch_size=48, shuffle=True, callbacks=[checkpoint_callback], validation_split=0.1)
# Out:
# Epoch 1/20
# 39/40 [============================>.] - ETA: 0s - loss: 1043.0486
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 4s 100ms/step - loss: 1033.7153 - val_loss: 59.4613
# Epoch 2/20
# 39/40 [============================>.] - ETA: 0s - loss: 39.4337
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 4s 103ms/step - loss: 39.3024 - val_loss: 25.4591
# Epoch 3/20
# 39/40 [============================>.] - ETA: 0s - loss: 18.7492
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 4s 102ms/step - loss: 18.7122 - val_loss: 13.4522
# Epoch 4/20
# 40/40 [==============================] - ETA: 0s - loss: 11.1521
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 5s 119ms/step - loss: 11.1521 - val_loss: 9.5757
# Epoch 5/20
# 39/40 [============================>.] - ETA: 0s - loss: 8.9431
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 5s 129ms/step - loss: 8.9428 - val_loss: 8.4893
# Epoch 6/20
# 39/40 [============================>.] - ETA: 0s - loss: 8.2239
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 6s 141ms/step - loss: 8.2048 - val_loss: 7.9537
# Epoch 7/20
# 40/40 [==============================] - ETA: 0s - loss: 7.7379
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 6s 143ms/step - loss: 7.7379 - val_loss: 7.5111
# Epoch 8/20
# 39/40 [============================>.] - ETA: 0s - loss: 7.3096
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 5s 137ms/step - loss: 7.3226 - val_loss: 7.1096
# Epoch 9/20
# 39/40 [============================>.] - ETA: 0s - loss: 6.9416
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 5s 118ms/step - loss: 6.9427 - val_loss: 6.7317
# Epoch 10/20
# 39/40 [============================>.] - ETA: 0s - loss: 6.5859
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 5s 123ms/step - loss: 6.5809 - val_loss: 6.3594
# Epoch 11/20
# 39/40 [============================>.] - ETA: 0s - loss: 6.1849
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 4s 109ms/step - loss: 6.1805 - val_loss: 5.9190
# Epoch 12/20
# 39/40 [============================>.] - ETA: 0s - loss: 5.7918
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 5s 132ms/step - loss: 5.8018 - val_loss: 5.5983
# Epoch 13/20
# 39/40 [============================>.] - ETA: 0s - loss: 5.5052
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 5s 117ms/step - loss: 5.4939 - val_loss: 5.2888
# Epoch 14/20
# 39/40 [============================>.] - ETA: 0s - loss: 5.2164
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 4s 109ms/step - loss: 5.2172 - val_loss: 5.0256
# Epoch 15/20
# 39/40 [============================>.] - ETA: 0s - loss: 4.9634
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 4s 104ms/step - loss: 4.9635 - val_loss: 4.7707
# Epoch 16/20
# 39/40 [============================>.] - ETA: 0s - loss: 4.7333
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 4s 113ms/step - loss: 4.7270 - val_loss: 4.5382
# Epoch 17/20
# 39/40 [============================>.] - ETA: 0s - loss: 4.5111
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 4s 111ms/step - loss: 4.5114 - val_loss: 4.3250
# Epoch 18/20
# 39/40 [============================>.] - ETA: 0s - loss: 4.3012
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 5s 130ms/step - loss: 4.3126 - val_loss: 4.1345
# Epoch 19/20
# 40/40 [==============================] - ETA: 0s - loss: 4.1263
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 5s 136ms/step - loss: 4.1263 - val_loss: 3.9450
# Epoch 20/20
# 39/40 [============================>.] - ETA: 0s - loss: 3.9411
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# INFO:tensorflow:Assets written to: models/mel_22050_1000_MSE/assets
# 40/40 [==============================] - 6s 141ms/step - loss: 3.9461 - val_loss: 3.7681

# %% [markdown]
# # Predict and Convert to Audio

# %%
pred = model.predict(X_test)
# Out:
# 29/29 [==============================] - 1s 25ms/step

# %% [markdown]
# # Compare Spectrograms of Predicted vs. Actual

# %%
reshaped_pred = pred.reshape(pred.shape[:-1])
reshaped_actual = X_test.reshape(X_test.shape[:-1])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
librosa.display.specshow(reshaped_pred[0], x_axis="time", y_axis="log", ax=ax1)
librosa.display.specshow(reshaped_actual[0], x_axis="time", y_axis="log", ax=ax2)
fig.savefig("asdf.png")

# %%
np.min(pred)
# Out:
# -84.40791
