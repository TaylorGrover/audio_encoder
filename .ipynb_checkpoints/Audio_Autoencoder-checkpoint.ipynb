# %% [markdown]
# # Data Loading and Preprocessing

# %%
from autoencoder import *
import glob
from IPython.display import Audio, SVG
# Out:
# 2022-12-06 13:20:41.380258: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-06 13:20:41.383666: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-06 13:20:41.383675: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
def get_audio(filepaths, num_vectors=100, sr=22050):
    """
    Currently really slow: approximately 34 files read per second, but there are
    over 100,000 files
    """
    zipped_fname = f"raw_audio_{sr}.zip"
    audio_fname = f"raw_audio_{sr}.npy"
    audio = []
    np.random.shuffle(filepaths)
    start = time.time()
    random_indices = [i for i in range(num_vectors)]
    np.random.shuffle(random_indices)
    '''with ProcessPoolExecutor(max_workers=3) as exe:
        completed = exe.map(get_single_file, filepaths[:num_vectors], repeat(sr), chunksize=40)
        for item in completed:
            if item.shape[0] == sr:
                audio.append(item)'''
    if os.path.isfile(zipped_fname):
        with zipfile.ZipFile(zipped_fname, "r") as zip_ref:
            with zip_ref.open(audio_fname) as unzipped:
                audio = np.load(unzipped)
                print(time.time() - start)
                return audio[random_indices]
    for i, path in enumerate(filepaths):
        if i >= num_vectors:
            break
        X, sample_rate = librosa.load(path, sr=sr)
        if X.shape[0] != sample_rate:
            X = librosa.util.fix_length(X, size=sr)
        audio.append(X)
    print(time.time() - start)
    with zipfile.ZipFile(zipped_fname, "w") as zip_ref:
        np.save(audio_fname.replace(".npy", ""), audio)
        zip_ref.write(audio_bfname)
    return np.array(audio, dtype=np.float32)[random_indices]

# %%
sr = 8000
n_mels = 128
fix_length=44
filepaths = get_all_files("wav")
audio = get_audio(filepaths, num_vectors=3000, sr=sr, )
# Out:
# 0.11820650100708008

# %%
def conv_data(audio, sr, mels=64, fix_length=44):
    ### Long operation: convert raw audio to melspectrogram
    start = time.time()
    mel = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=mels)
    mel = librosa.util.fix_length(mel, size=fix_length)
    print(mel.shape)
    db = librosa.amplitude_to_db(mel, ref=np.max)
    print(time.time() - start)
    ### Reshape mel spectrogram so each [row][col] is a singleton array (for keras)
    db = db.reshape(*db.shape, 1) # This may not be a good idea

    X_train, X_test = train_test_split(db, test_size=0.3)
    return X_train, X_test

# %%
X_train, X_test = conv_data(audio, sr, mels=n_mels, fix_length=fix_length)
# Out:
# (3000, 128, 44)
# 1.5551321506500244

# %% [markdown]
# # Audio Visualization

# %%
Audio(audio[0], rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(audio[0])

# %%
fig, ax = plt.subplots(figsize=(10, 6))
index = np.random.randint(0, len(audio))
mel = librosa.feature.melspectrogram(y=audio[0], sr=sr, n_mels=n_mels)
mel_to_db = librosa.amplitude_to_db(mel, ref=np.max)
librosa.display.specshow(mel_to_db, x_axis="time", y_axis="log", ax=ax)
reshaped = mel.reshape(*mel.shape, 1)
fig.savefig("asdf.png")
mel.shape
# Out:
# (64, 16)

# %% [markdown]
# # Get Convolutional Model

# %%
def get_conv_model(input_shape, latent):
    Input = tf.keras.Input(shape=input_shape)
    #encoder = Sequential()
    x = layers.Conv2D(2 * latent, (3, 3), activation="leaky_relu", padding="same", input_shape=input_shape)(Input)
    x = layers.MaxPool2D((2, 2), padding="same")(x)
    x = layers.Conv2D(latent, (3, 3), activation="leaky_relu", padding="same")(x)
    #print(encoder.summary())
    #latent = encoder(Input)
    #decoder = Sequential()
    x = layers.Conv2DTranspose(latent * 2, (3, 3), strides=2, activation="leaky_relu", padding="same")(x)
    x = layers.Conv2D(1, (1, 1), activation="linear")(x)
    print(x.shape)
    #print(decoder.summary())

    model = Model(inputs=Input, outputs=x)
    print(model.summary())
    model.compile(optimizer="adam", loss="MSE")
    return model

# %%
latent = 32
print(X_train.shape[1:])
mel_autoencoder_model = get_conv_model(X_train.shape[1:], latent)
# Out:
# (128, 44, 1)
# (None, 128, 44, 1)
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 128, 44, 1)]      0
#
#  conv2d_16 (Conv2D)          (None, 128, 44, 64)       640
#
#  max_pooling2d_6 (MaxPooling  (None, 64, 22, 64)       0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 64, 22, 32)        18464
#
#  conv2d_transpose_6 (Conv2DT  (None, 128, 44, 64)      18496
#  ranspose)
#
#  conv2d_18 (Conv2D)          (None, 128, 44, 1)        65
#
# =================================================================
# Total params: 37,665
# Trainable params: 37,665
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
X_train.shape
# Out:
# (2100, 128, 44, 1)

# %%
dot = tf.keras.utils.model_to_dot(
    mel_autoencoder_model,
    show_shapes=True,
    expand_nested=True,
    dpi=96,
    subgraph=False,
    show_layer_activations=True
)
SVG(dot.create(prog="dot", format="svg"))

# %%
model_name = f"mel_{sr}_{X_train.shape[1]}_{X_train.shape[2]}_{mel_autoencoder_model.loss}"
checkpoint_callback = get_checkpoint(model_name)
history = mel_autoencoder_model.fit(X_train, X_train, epochs=13, batch_size=48, shuffle=True, callbacks=[checkpoint_callback], validation_split=0.1)
plot_history(model_name, history, "loss")
# Out:
# Epoch 1/13
# 11/40 [=======>......................] - ETA: 5s - loss: 0.9203
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [220], in <cell line: 3>()
#       1 model_name = f"mel_{sr}_{X_train.shape[1]}_{X_train.shape[2]}_{mel_autoencoder_model.loss}"
#       2 checkpoint_callback = get_checkpoint(model_name)
# ----> 3 history = mel_autoencoder_model.fit(X_train, X_train, epochs=13, batch_size=48, shuffle=True, callbacks=[checkpoint_callback], validation_split=0.1)
#       4 plot_history(model_name, history, "loss")
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Predict and Convert to Audio

# %%
mel_autoencoder_model = tf.keras.models.load_model(os.path.join("models", model_name))
pred = mel_autoencoder_model.predict(X_test)
# Out:
# 29/29 [==============================] - 1s 45ms/step

# %% [markdown]
# # Compare Spectrograms of Predicted vs. Actual

# %%
reshaped_pred = pred.reshape(pred.shape[:-1])
reshaped_actual = X_test.reshape(X_test.shape[:-1])

# %% [markdown]
# ## Spectrogram Stats

# %%
pred_mean = np.mean(reshaped_pred, axis=0)
actual_mean = np.mean(reshaped_actual, axis=0)
pred_min = np.min(reshaped_pred, axis=0)
actual_min = np.min(reshaped_actual, axis=0)
pred_max = np.max(reshaped_pred, axis=0)
actual_max = np.max(reshaped_actual, axis=0)
print(pred_mean)
print(actual_mean)
print(pred_min)
print(actual_min)
print(pred_max)
print(actual_max)
# Out:
# [[-68.115906 -77.67692  -77.69263  ... -81.32899  -76.2619   -76.975655]
#  [-77.54572  -76.50502  -81.12392  ... -80.78638  -78.504196 -80.41339 ]
#  [-79.979774 -81.98688  -81.896065 ... -80.65129  -80.414894 -81.03195 ]
#  ...
#  [-81.82364  -81.09684  -79.9959   ... -79.97655  -79.60072  -79.359314]
#  [-73.18279  -77.5776   -79.93157  ... -80.20291  -76.08891  -76.04257 ]
#  [-74.554184 -77.43305  -81.24105  ... -79.6649   -78.102425 -76.964455]]
# [[-78.78578  -77.595116 -77.42472  ... -80.       -80.       -80.      ]
#  [-79.13772  -78.585686 -78.498856 ... -80.       -80.       -80.      ]
#  [-79.915054 -79.90274  -79.81169  ... -80.       -80.       -80.      ]
#  ...
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]
# [[-69.684746 -80.17642  -79.998314 ... -81.329865 -76.26175  -76.97482 ]
#  [-81.64537  -82.40655  -86.081375 ... -80.786835 -78.50398  -80.41302 ]
#  [-82.674255 -86.110275 -85.461754 ... -80.65123  -80.4156   -81.03249 ]
#  ...
#  [-81.824646 -81.09836  -80.61837  ... -79.97641  -79.60003  -79.358925]
#  [-73.218636 -77.627045 -80.3255   ... -80.20229  -76.088394 -76.04203 ]
#  [-74.55375  -77.43317  -81.26924  ... -79.66554  -78.10315  -76.96428 ]]
# [[-80. -80. -80. ... -80. -80. -80.]
#  [-80. -80. -80. ... -80. -80. -80.]
#  [-80. -80. -80. ... -80. -80. -80.]
#  ...
#  [-80. -80. -80. ... -80. -80. -80.]
#  [-80. -80. -80. ... -80. -80. -80.]
#  [-80. -80. -80. ... -80. -80. -80.]]
# [[-36.937527 -33.88513  -38.856533 ... -81.329865 -76.26175  -76.97482 ]
#  [-34.918797 -27.465939 -33.176064 ... -80.786835 -78.50398  -80.41302 ]
#  [-71.24417  -68.62653  -66.87883  ... -80.65123  -80.4156   -81.03249 ]
#  ...
#  [-81.60073  -80.78897  -79.6957   ... -79.97641  -79.60003  -79.358925]
#  [-73.16202  -77.53671  -79.862015 ... -80.20229  -76.088394 -76.04203 ]
#  [-74.45479  -77.34163  -81.092545 ... -79.66554  -78.10315  -76.96428 ]]
# [[-31.208511 -25.37253  -26.36401  ... -80.       -80.       -80.      ]
#  [-36.309788 -30.554663 -31.373125 ... -80.       -80.       -80.      ]
#  [-63.499855 -62.765343 -55.097317 ... -80.       -80.       -80.      ]
#  ...
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.set_title("Predicted")
ax2.set_title("Actual")
index = np.random.randint(0, len(reshaped_pred))
diff = np.abs(reshaped_pred[index]) - 80
filtered = np.abs(diff) < 10
res = filtered * diff + reshaped_pred[index]
librosa.display.specshow(res, x_axis="time", y_axis="log", ax=ax1)
librosa.display.specshow(reshaped_actual[index], x_axis="time", y_axis="log", ax=ax2)
fig.savefig("asdf.png")

# %%
amp_pred = librosa.db_to_amplitude(res)
amp_actual = librosa.db_to_amplitude(reshaped_actual[index])
audio_pred = librosa.feature.inverse.mel_to_audio(amp_pred, sr=sr)
audio_actual = librosa.feature.inverse.mel_to_audio(amp_actual, sr=sr)
print(np.min(audio_pred))
print(np.min(audio_actual))
# Out:
# -0.006032435
# -0.0066822954

# %%
sf.write("best.wav", audio_pred * 200, sr)
print(sr)
Audio(audio_pred, rate=sr)
# Out:
# 8000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mel = librosa.feature.melspectrogram(y=audio[index], sr=sr, n_mels=n_mels)
db = librosa.amplitude_to_db(mel, np.max)
amp = librosa.db_to_amplitude(db)
out = librosa.feature.inverse.mel_to_audio(amp, sr=sr)
Audio(out, rate=sr)
# Out:
# /tmp/ipykernel_164265/3831627576.py:2: FutureWarning: Pass ref=<function amax at 0x7f9108448160> as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   db = librosa.amplitude_to_db(mel, np.max)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Get mel/audio pairs (train/test)

# %%
# Out:
# 0.7328472137451172
# 0.7410297393798828
# 0.7468295097351074
# 0.7790043354034424
# 0.7661738395690918
# 0.7558205127716064
# 0.7626137733459473
# 0.7677643299102783
# 0.7744231224060059
# 0.7723429203033447
# 0.778270959854126
# 0.775733470916748
# 0.7888529300689697
# 0.7891786098480225
# 0.7976646423339844
# 0.8267674446105957
# 0.8042020797729492
# 0.8451766967773438
# 0.8363702297210693
# 0.8798685073852539
# 0.9295182228088379
# 1.3592629432678223
# 2.2379848957061768
# 1.2346901893615723
# 0.9925367832183838
# 1.0787196159362793
# 0.8945860862731934
# 0.8660118579864502
# 0.9133508205413818
# 0.9089899063110352
# 0.9007201194763184
# 0.8644344806671143
# 1.023611068725586
# 0.8984928131103516
# 0.8487706184387207
# 0.8420066833496094
# 0.8480041027069092
# 0.9021742343902588
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [102], in <cell line: 5>()
#       5 for i in range(16, len(amps), 16):
#       6     start = time.time()
# ----> 7     artifacts = librosa.feature.inverse.mel_to_audio(amps[i:i+16], sr=sr)
#       8     new = np.concatenate((new, artifacts), axis=0)
#       9     print(time.time() - start)
#
# File ~/.local/lib/python3.8/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~/.local/lib/python3.8/site-packages/librosa/feature/inverse.py:160, in mel_to_audio(M, sr, n_fft, hop_length, win_length, window, center, pad_mode, power, n_iter, length, dtype, **kwargs)
#     106 """Invert a mel power spectrogram to audio using Griffin-Lim.
#     107
#     108 This is primarily a convenience wrapper for:
#    (...)
#     155 librosa.feature.inverse.mel_to_stft
#     156 """
#     158 stft = mel_to_stft(M, sr=sr, n_fft=n_fft, power=power, **kwargs)
# --> 160 return griffinlim(
#     161     stft,
#     162     n_iter=n_iter,
#     163     hop_length=hop_length,
#     164     win_length=win_length,
#     165     n_fft=n_fft,
#     166     window=window,
#     167     center=center,
#     168     dtype=dtype,
#     169     length=length,
#     170     pad_mode=pad_mode,
#     171 )
#
# File ~/.local/lib/python3.8/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:2460, in griffinlim(S, n_iter, hop_length, win_length, n_fft, window, center, dtype, length, pad_mode, momentum, init, random_state)
#    2448 inverse = istft(
#    2449     S * angles,
#    2450     hop_length=hop_length,
#    (...)
#    2456     length=length,
#    2457 )
#    2459 # Rebuild the spectrogram
# -> 2460 rebuilt = stft(
#    2461     inverse,
#    2462     n_fft=n_fft,
#    2463     hop_length=hop_length,
#    2464     win_length=win_length,
#    2465     window=window,
#    2466     center=center,
#    2467     pad_mode=pad_mode,
#    2468 )
#    2470 # Update our phase estimates
#    2471 angles[:] = rebuilt - (momentum / (1 + momentum)) * tprev
#
# File ~/.local/lib/python3.8/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~/.local/lib/python3.8/site-packages/librosa/core/spectrum.py:254, in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode)
#     251 for bl_s in range(0, stft_matrix.shape[-1], n_columns):
#     252     bl_t = min(bl_s + n_columns, stft_matrix.shape[-1])
# --> 254     stft_matrix[..., bl_s:bl_t] = fft.rfft(
#     255         fft_window * y_frames[..., bl_s:bl_t], axis=-2
#     256     )
#     257 return stft_matrix
#
# File <__array_function__ internals>:180, in rfft(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/fft/_pocketfft.py:409, in rfft(a, n, axis, norm)
#     407     n = a.shape[axis]
#     408 inv_norm = _get_forward_norm(n, norm)
# --> 409 output = _raw_fft(a, n, axis, True, True, inv_norm)
#     410 return output
#
# File ~/.local/lib/python3.8/site-packages/numpy/fft/_pocketfft.py:73, in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      71 else:
#      72     a = swapaxes(a, axis, -1)
# ---> 73     r = pfi.execute(a, is_real, is_forward, fct)
#      74     r = swapaxes(r, axis, -1)
#      75 return r
#
# KeyboardInterrupt:

# %% [markdown]
# # Remove Noise from Processed Audio

# %% [markdown]
# ## Get Noisy Audio Through Multiple Transformations

# %%
3000 * 7680 * 64 /
# Out:
# 184320000.0

# %% [markdown]
# # Try Different Numbers (Measure Loss)
